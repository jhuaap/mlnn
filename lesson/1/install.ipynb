# %% [markdown]
# # Install Party

# %% [markdown]
# ### Install Apps
#
# Make sure you have all of the following programs installed.

# %% [markdown]
# **NOTE** Uninstall Anaconda 2 if you have it installed.
#
# - [Anaconda 3 (Python 3)](https://www.continuum.io/downloads) - This installs Python and many needed libraries on your computer in a ready to go manner
# - [Sublime Text 3](https://www.sublimetext.com/3) - This is a useful Text Editor that allows you to edit code. We will use this seldomly.
# - XCode Command Line Tools (Mac Only). In the `terminal` Copy and paste: `xcode-select --install` ( This installs necessary compilers for Python to work some magic under the hood.)
# - [Homebrew (Mac Only)](http://brew.sh/) - This provides an easy method of installing (typically complicated) applications.
# - [iTerm2 (Mac Only)](https://www.iterm2.com/) - This is a nicer Terminal to use instead of what comes default with Mac.
# - [Git (Windows Only)](https://git-scm.com/downloads) - This installs Git along with a terminal and bash tools.

# %% [markdown]
# ### Install Extra Packages

# %% [markdown]
# Run this in your terminal:
#
# `pip install version_information arrow seaborn ujson`

# %% [markdown]
# ### Check Package Versions

# %%
import numpy
import scipy
import matplotlib
import pandas
import statsmodels
import seaborn
import sklearn
import nltk

print("numpy:", numpy.__version__)
print("scipy:", scipy.__version__)
print("matplotlib:", matplotlib.__version__)
print("statsmodels:", statsmodels.__version__)
print("pandas:", pandas.__version__)
print("seaborn:", seaborn.__version__)
print("sklearn:", sklearn.__version__)
print("nltk:", nltk.__version__)
# Out:
# numpy: 1.10.4
# scipy: 0.17.0
# matplotlib: 1.5.1
# statsmodels: 0.6.1
# pandas: 0.17.1
# seaborn: 0.7.0
# sklearn: 0.17
# nltk: 3.1
